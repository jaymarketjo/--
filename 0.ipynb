# %%
# 这是一个简单的示例代码，演示了如何使用 Jupyter Notebook 进行交互式计算和数据可视化

import numpy as np
import matplotlib.pyplot as plt

# 生成一些随机数据
x = np.linspace(0, 10, 100)
y = np.sin(x)

# 在 Notebook 中显示数据可视化结果
plt.plot(x, y)
plt.title('Sin Function')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
